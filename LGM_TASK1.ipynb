# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyan4636/fibonacci-series/blob/main/LGM_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Image to pencil Sketch with Python
#Task 1
#LGM(VIP)Data Science

from google.colab.patches import cv2_imshow
 
import cv2

img = cv2.imread("yash.jpg")

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x480 at 0x7F89A2E161D0>
